# %% [markdown]
# # Task abstarction
# Link materi: https://achluky.github.io/visdat/week3/slide.pdf
#
# 1. Actions
#     - Analyze
#         - Consume (Discover, Present, Enjoy)
#         - Produce (Annotate, Record, Derive)
#     - Search
#         - Lookup
#         - Locate
#         - Browse
#         - Explore
#     - Query
#         - Identify
#         - Compare
#         - Summarize
# 2. Targets
#     - All Data
#         - Trends
#         - Outliers
#         - Features
#     - Attributes
#         - One
#             - Distribution (Extremes)
#         - Many
#             - Dependency, Correlation, Similarity
#     - Network Data
#         - Topology: Paths
#     - Spatial Data
#         - Shape

# %% [markdown]
# # Pre-test
#
# - Ganti "cell" yang berisi dengan tanda tanya dengan kategori action atau target sesuai dengan link materi.

# %% [markdown]
# | No skenario| Domain Task (Pertanyaan User) | Action (Why) | Target (What) | Visual Mapping |
# | :--- | :--- | :--- | :--- | :--- |
# | 1 | Bagaimana tren harapan hidup dunia dari 1952-2007? | Analyze: Consume | Trends | Line Chart |
# | 2 | Adakah negara yang sangat kaya tapi harapan hidupnya rendah? | Search: Locate | Outliers | Scatterplot + Annotation |
# | 3 | Bandingkan sebaran pendapatan antar benua. | ? | ? | ?|
# | 4 | Siapa 5 besar negara dengan populasi terbanyak di Asia? | ? | ? | ? |
# | 5 | Apakah ukuran meja makan memengaruhi jumlah tip di restoran? | ? | ? | ? |
# | 6 | Lihat kemiripan pola belanja antara pria dan wanita. | ? | ? | ? |
# | 7 | Cari hari apa yang paling ramai di restoran (puncak kunjungan). | ? | ? | ? |
# | 8 | Buat kolom 'Proporsi Tip' dari total tagihan. | ? | ? | ? |
# | 9 | Petakan lokasi geografis penyebaran penyakit. | ? | ? | ? |
# | 10 | Bagaimana struktur organisasi/koneksi antar aktor ini? | ? | ? | ? |

# %% [markdown]
# > selamat berpuasa (untuk yang melaksanakan) ... semoga semakin banyak interaksi kita dengan al-quran - ALR -
